# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

df = pd.read_csv("ecom.csv")

df.drop_duplicates(inplace=True)

df['order_date'] = pd.to_datetime(df['order_date'])

df = df[df['price'] > 0]

df['revenue'] = df['price'] * df['quantity']

df.to_csv("clean_ecommerce_sales.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File G:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'order_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 7
#       3 df = pd.read_csv("ecom.csv")
#       5 df.drop_duplicates(inplace=True)
# ----> 7 df['order_date'] = pd.to_datetime(df['order_date'])
#       9 df = df[df['price'] > 0]
#      11 df['revenue'] = df['price'] * df['quantity']
#
# File G:\anaconda\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File G:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'order_date'

# %%
df = pd.read_csv("ecom.csv")

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card         14-04-23
# 1           738.56         PayPal         30-07-23
# 2           178.34    Credit Card         17-09-23
# 3           401.09            UPI         21-06-23
# 4           594.83    Net Banking         29-10-24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    50000 non-null  int64
#  1   User_Name         50000 non-null  object
#  2   Age               50000 non-null  int64
#  3   Country           50000 non-null  object
#  4   Product_Category  50000 non-null  object
#  5   Purchase_Amount   50000 non-null  float64
#  6   Payment_Method    50000 non-null  object
#  7   Transaction_Date  50000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.1+ MB

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.describe()
# Out:
#        Transaction_ID           Age  Purchase_Amount
# count    50000.000000  50000.000000     50000.000000
# mean     25000.500000     43.968680       503.159793
# std      14433.901067     15.260578       286.563558
# min          1.000000     18.000000         5.040000
# 25%      12500.750000     31.000000       255.450000
# 50%      25000.500000     44.000000       503.110000
# 75%      37500.250000     57.000000       751.162500
# max      50000.000000     70.000000       999.980000

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# User_Name           0
# Age                 0
# Country             0
# Product_Category    0
# Purchase_Amount     0
# Payment_Method      0
# Transaction_Date    0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15072\1698716155.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15072\3773291137.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    50000 non-null  int64
#  1   User_Name         50000 non-null  object
#  2   Age               50000 non-null  int64
#  3   Country           50000 non-null  object
#  4   Product_Category  50000 non-null  object
#  5   Purchase_Amount   50000 non-null  float64
#  6   Payment_Method    50000 non-null  object
#  7   Transaction_Date  50000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 3.1+ MB

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'User_Name', 'Age', 'Country', 'Product_Category',
#        'Purchase_Amount', 'Payment_Method', 'Transaction_Date'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")

# %%
df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# %%
df['purchase_amount'] = pd.to_numeric(df['purchase_amount'])

# %%
df.describe()
# Out:
#        transaction_id           age  purchase_amount  \
# count    50000.000000  50000.000000     50000.000000
# mean     25000.500000     43.968680       503.159793
# min          1.000000     18.000000         5.040000
# 25%      12500.750000     31.000000       255.450000
# 50%      25000.500000     44.000000       503.110000
# 75%      37500.250000     57.000000       751.162500
# max      50000.000000     70.000000       999.980000
# std      14433.901067     15.260578       286.563558
#
#                  transaction_date
# count                       50000
# mean   2024-03-07 16:03:23.328000
# min           2023-01-04 00:00:00
# 25%           2023-08-31 00:00:00
# 50%           2024-03-07 00:00:00
# 75%           2024-09-06 00:00:00
# max           2025-12-02 00:00:00
# std                           NaN

# %%
df['product_category'].unique()
df['payment_method'].unique()
df['country'].unique()
# Out:
# array(['Mexico', 'India', 'France', 'Germany', 'Canada', 'Japan',
#        'Australia', 'Brazil', 'USA', 'UK'], dtype=object)

# %%
df['month'] = df['transaction_date'].dt.month

# %%
df['year'] = df['transaction_date'].dt.year

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    50000 non-null  int64
#  1   user_name         50000 non-null  object
#  2   age               50000 non-null  int64
#  3   country           50000 non-null  object
#  4   product_category  50000 non-null  object
#  5   purchase_amount   50000 non-null  float64
#  6   payment_method    50000 non-null  object
#  7   transaction_date  50000 non-null  datetime64[ns]
#  8   month             50000 non-null  int32
#  9   year              50000 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(2), object(4)
# memory usage: 3.4+ MB
#    transaction_id        user_name  age  country product_category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    purchase_amount payment_method transaction_date  month  year
# 0           780.69     Debit Card       2023-04-14      4  2023
# 1           738.56         PayPal       2023-07-30      7  2023
# 2           178.34    Credit Card       2023-09-17      9  2023
# 3           401.09            UPI       2023-06-21      6  2023
# 4           594.83    Net Banking       2024-10-29     10  2024

# %%
CREATE TABLE orders (
order_id INT,
order_date DATE,
customer_id INT,
product_id INT,
product_name VARCHAR(100),
category VARCHAR(50),
price DECIMAL(10,2),
quantity INT,
city VARCHAR(50),
payment_method VARCHAR(50)
);
# Out:
#   Cell In[24], line 1
#     CREATE TABLE orders (
#            ^
# SyntaxError: invalid syntax

# %%
import sqlite3

# %%
conn = sqlite3.connect("ecommerce.db")
cursor = conn.cursor()

# %%
cursor.execute("""
CREATE TABLE orders (
order_id INT,
order_date DATE,
customer_id INT,
product_id INT,
product_name VARCHAR(100),
category VARCHAR(50),
price DECIMAL(10,2),
quantity INT,
city VARCHAR(50),
payment_method VARCHAR(50)
)
""")

# %%
conn.commit()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('orders',)]

# %%
conn.close()

# %%
ecommerce_analysis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 ecommerce_analysis
#
# NameError: name 'ecommerce_analysis' is not defined

# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("ecom.csv")

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card         14-04-23
# 1           738.56         PayPal         30-07-23
# 2           178.34    Credit Card         17-09-23
# 3           401.09            UPI         21-06-23
# 4           594.83    Net Banking         29-10-24
